# %%
import pandas as pd
from metrics import model_experiment

# %%
# Data Import
df = pd.read_csv("C:/Users/lyes_/Desktop/Second Project Hab/second-project/data/machine failure.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Data Import
# ----> 2 df = pd.read_csv("C:/Users/lyes_/Desktop/Second Project Hab/second-project/data/machine failure.csv")
#       3 df
#
# NameError: name 'pd' is not defined

# %%
features = ['Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]', 'Air temperature [K]', 'Process temperature [K]']
target = 'Machine failure'

# %%
X = df[features]
y = df[target]

# %%
from sklearn.ensemble import RandomForestClassifier

rf_args = {
    'n_estimators': 100, 
    'random_state': 42
}

model, metrics = model_experiment(X, y, RandomForestClassifier, rf_args)
# Out:
# Beginning Experiment for Model: <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1939
#            1       0.84      0.61      0.70        61
#
#     accuracy                           0.98      2000
#    macro avg       0.91      0.80      0.85      2000
# weighted avg       0.98      0.98      0.98      2000
#
#
# ROC-AUC Score: 0.8014736343729656
#
# Confusion Matrix:
# [[1932    7]
#  [  24   37]]
# --------------------------------------------------

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier, RadiusNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.preprocessing import MinMaxScaler

models = [
    LogisticRegression,
    KNeighborsClassifier,
    # RadiusNeighborsClassifier,
    SVC,
    GaussianNB,
    BernoulliNB,
    DecisionTreeClassifier,
    RandomForestClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier
]

for model in models:
    model_experiment(X, y, model)
# Out:
# Beginning Experiment for Model: <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1939
#            1       0.62      0.26      0.37        61
#
#     accuracy                           0.97      2000
#    macro avg       0.80      0.63      0.68      2000
# weighted avg       0.97      0.97      0.97      2000
#
#
# ROC-AUC Score: 0.6285688921955715
#
# Confusion Matrix:
# [[1929   10]
#  [  45   16]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1939
#            1       0.57      0.13      0.21        61
#
#     accuracy                           0.97      2000
#    macro avg       0.77      0.56      0.60      2000
# weighted avg       0.96      0.97      0.96      2000
#
#
# ROC-AUC Score: 0.5640265812189822
#
# Confusion Matrix:
# [[1933    6]
#  [  53    8]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.svm._classes.SVC'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1939
#            1       1.00      0.03      0.06        61
#
#     accuracy                           0.97      2000
#    macro avg       0.99      0.52      0.52      2000
# weighted avg       0.97      0.97      0.96      2000
#
#
# ROC-AUC Score: 0.5163934426229508
#
# Confusion Matrix:
# [[1939    0]
#  [  59    2]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.naive_bayes.GaussianNB'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1939
#            1       0.36      0.21      0.27        61
#
#     accuracy                           0.96      2000
#    macro avg       0.67      0.60      0.62      2000
# weighted avg       0.96      0.96      0.96      2000
#
#
# ROC-AUC Score: 0.6006264848366997
#
# Confusion Matrix:
# [[1916   23]
#  [  48   13]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.naive_bayes.BernoulliNB'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1939
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.97      2000
#    macro avg       0.48      0.50      0.49      2000
# weighted avg       0.94      0.97      0.95      2000
#
#
# ROC-AUC Score: 0.5
#
# Confusion Matrix:
# [[1939    0]
#  [  61    0]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1939
#            1       0.67      0.74      0.70        61
#
#     accuracy                           0.98      2000
#    macro avg       0.83      0.86      0.85      2000
# weighted avg       0.98      0.98      0.98      2000
#
#
# ROC-AUC Score: 0.8631794316827164
#
# Confusion Matrix:
# [[1917   22]
#  [  16   45]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# c:\Users\lyes_\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\lyes_\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\lyes_\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\lyes_\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1939
#            1       0.86      0.61      0.71        61
#
#     accuracy                           0.98      2000
#    macro avg       0.92      0.80      0.85      2000
# weighted avg       0.98      0.98      0.98      2000
#
#
# ROC-AUC Score: 0.8017314992517691
#
# Confusion Matrix:
# [[1933    6]
#  [  24   37]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>
# c:\Users\lyes_\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1939
#            1       0.67      0.49      0.57        61
#
#     accuracy                           0.98      2000
#    macro avg       0.83      0.74      0.78      2000
# weighted avg       0.97      0.98      0.98      2000
#
#
# ROC-AUC Score: 0.7420336661622097
#
# Confusion Matrix:
# [[1924   15]
#  [  31   30]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.ensemble._gb.GradientBoostingClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1939
#            1       0.81      0.56      0.66        61
#
#     accuracy                           0.98      2000
#    macro avg       0.90      0.78      0.83      2000
# weighted avg       0.98      0.98      0.98      2000
#
#
# ROC-AUC Score: 0.7766256055597358
#
# Confusion Matrix:
# [[1931    8]
#  [  27   34]]
# --------------------------------------------------

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier, RadiusNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.preprocessing import MinMaxScaler

models = [
    LogisticRegression,
    KNeighborsClassifier,
    # RadiusNeighborsClassifier,
    SVC,
    GaussianNB,
    BernoulliNB,
    DecisionTreeClassifier,
    RandomForestClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier
]

scalers = [
    MinMaxScaler,
    MinMaxScaler,
    # MinMaxScaler,
    MinMaxScaler,
    MinMaxScaler,
    MinMaxScaler,
    None,
    None,
    None,
    None
]

for model, scaler in zip(models, scalers):
    model_experiment(X, y, model, scaling=scaler)
# Out:
# Beginning Experiment for Model: <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1939
#            1       1.00      0.02      0.03        61
#
#     accuracy                           0.97      2000
#    macro avg       0.98      0.51      0.51      2000
# weighted avg       0.97      0.97      0.96      2000
#
#
# ROC-AUC Score: 0.5081967213114754
#
# Confusion Matrix:
# [[1939    0]
#  [  60    1]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1939
#            1       0.73      0.26      0.39        61
#
#     accuracy                           0.97      2000
#    macro avg       0.85      0.63      0.69      2000
# weighted avg       0.97      0.97      0.97      2000
#
#
# ROC-AUC Score: 0.6296003517107855
#
# Confusion Matrix:
# [[1933    6]
#  [  45   16]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.svm._classes.SVC'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1939
#            1       0.90      0.15      0.25        61
#
#     accuracy                           0.97      2000
#    macro avg       0.94      0.57      0.62      2000
# weighted avg       0.97      0.97      0.96      2000
#
#
# ROC-AUC Score: 0.5735126269244751
#
# Confusion Matrix:
# [[1938    1]
#  [  52    9]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.naive_bayes.GaussianNB'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1939
#            1       0.36      0.21      0.27        61
#
#     accuracy                           0.96      2000
#    macro avg       0.67      0.60      0.62      2000
# weighted avg       0.96      0.96      0.96      2000
#
#
# ROC-AUC Score: 0.6006264848366997
#
# Confusion Matrix:
# [[1916   23]
#  [  48   13]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.naive_bayes.BernoulliNB'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1939
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.97      2000
#    macro avg       0.48      0.50      0.49      2000
# weighted avg       0.94      0.97      0.95      2000
#
#
# ROC-AUC Score: 0.4997421351211965
#
# Confusion Matrix:
# [[1938    1]
#  [  61    0]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1939
#            1       0.62      0.70      0.66        61
#
#     accuracy                           0.98      2000
#    macro avg       0.81      0.85      0.83      2000
# weighted avg       0.98      0.98      0.98      2000
#
#
# ROC-AUC Score: 0.8457545295445514
#
# Confusion Matrix:
# [[1913   26]
#  [  18   43]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1939
#            1       0.86      0.61      0.71        61
#
#     accuracy                           0.98      2000
#    macro avg       0.92      0.80      0.85      2000
# weighted avg       0.98      0.98      0.98      2000
#
#
# ROC-AUC Score: 0.8017314992517691
#
# Confusion Matrix:
# [[1933    6]
#  [  24   37]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>
# c:\Users\lyes_\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1939
#            1       0.67      0.49      0.57        61
#
#     accuracy                           0.98      2000
#    macro avg       0.83      0.74      0.78      2000
# weighted avg       0.97      0.98      0.98      2000
#
#
# ROC-AUC Score: 0.7420336661622097
#
# Confusion Matrix:
# [[1924   15]
#  [  31   30]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.ensemble._gb.GradientBoostingClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1939
#            1       0.82      0.59      0.69        61
#
#     accuracy                           0.98      2000
#    macro avg       0.90      0.79      0.84      2000
# weighted avg       0.98      0.98      0.98      2000
#
#
# ROC-AUC Score: 0.7930190481826866
#
# Confusion Matrix:
# [[1931    8]
#  [  25   36]]
# --------------------------------------------------

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier, RadiusNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.preprocessing import MinMaxScaler

models = [
    LogisticRegression,
    KNeighborsClassifier,
    # RadiusNeighborsClassifier,
    SVC,
    GaussianNB,
    BernoulliNB,
    DecisionTreeClassifier,
    RandomForestClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier
]

scalers = [
    MinMaxScaler,
    # MinMaxScaler,
    MinMaxScaler,
    MinMaxScaler,
    MinMaxScaler,
    MinMaxScaler,
    None,
    None,
    None,
    None
]

for model, scaler in zip(models, scalers):
    model_experiment(X, y, model, scaling=scaler, oversample=0.7, undersample=1)
# Out:
# Beginning Experiment for Model: <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.82      0.90      1939
#            1       0.13      0.84      0.22        61
#
#     accuracy                           0.82      2000
#    macro avg       0.56      0.83      0.56      2000
# weighted avg       0.97      0.82      0.88      2000
#
#
# ROC-AUC Score: 0.828037944182822
#
# Confusion Matrix:
# [[1590  349]
#  [  10   51]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95      1939
#            1       0.23      0.87      0.36        61
#
#     accuracy                           0.91      2000
#    macro avg       0.61      0.89      0.65      2000
# weighted avg       0.97      0.91      0.93      2000
#
#
# ROC-AUC Score: 0.8874948215659584
#
# Confusion Matrix:
# [[1757  182]
#  [   8   53]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.svm._classes.SVC'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95      1939
#            1       0.22      0.87      0.35        61
#
#     accuracy                           0.90      2000
#    macro avg       0.61      0.89      0.65      2000
# weighted avg       0.97      0.90      0.93      2000
#
#
# ROC-AUC Score: 0.8851740376567268
#
# Confusion Matrix:
# [[1748  191]
#  [   8   53]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.naive_bayes.GaussianNB'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.85      0.91      1939
#            1       0.12      0.69      0.21        61
#
#     accuracy                           0.84      2000
#    macro avg       0.56      0.77      0.56      2000
# weighted avg       0.96      0.84      0.89      2000
#
#
# ROC-AUC Score: 0.767418561198522
#
# Confusion Matrix:
# [[1641  298]
#  [  19   42]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.naive_bayes.BernoulliNB'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.01      0.03      1939
#            1       0.03      1.00      0.06        61
#
#     accuracy                           0.04      2000
#    macro avg       0.52      0.51      0.04      2000
# weighted avg       0.97      0.04      0.03      2000
#
#
# ROC-AUC Score: 0.5064466219700876
#
# Confusion Matrix:
# [[  25 1914]
#  [   0   61]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97      1939
#            1       0.33      0.70      0.45        61
#
#     accuracy                           0.95      2000
#    macro avg       0.66      0.83      0.71      2000
# weighted avg       0.97      0.95      0.96      2000
#
#
# ROC-AUC Score: 0.829766907058734
#
# Confusion Matrix:
# [[1851   88]
#  [  18   43]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98      1939
#            1       0.37      0.79      0.50        61
#
#     accuracy                           0.95      2000
#    macro avg       0.68      0.87      0.74      2000
# weighted avg       0.97      0.95      0.96      2000
#
#
# ROC-AUC Score: 0.872297702888932
#
# Confusion Matrix:
# [[1857   82]
#  [  13   48]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>
# c:\Users\lyes_\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95      1939
#            1       0.22      0.80      0.34        61
#
#     accuracy                           0.91      2000
#    macro avg       0.61      0.86      0.65      2000
# weighted avg       0.97      0.91      0.93      2000
#
#
# ROC-AUC Score: 0.8559972607140743
#
# Confusion Matrix:
# [[1762  177]
#  [  12   49]]
# --------------------------------------------------
#
# Beginning Experiment for Model: <class 'sklearn.ensemble._gb.GradientBoostingClassifier'>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96      1939
#            1       0.29      0.84      0.43        61
#
#     accuracy                           0.93      2000
#    macro avg       0.64      0.89      0.70      2000
# weighted avg       0.97      0.93      0.95      2000
#
#
# ROC-AUC Score: 0.8863154067924146
#
# Confusion Matrix:
# [[1816  123]
#  [  10   51]]
# --------------------------------------------------
